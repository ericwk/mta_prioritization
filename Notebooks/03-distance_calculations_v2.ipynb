# %%
import pandas as pd
import pickle
from haversine import haversine

# %%
with open('foursquare_POIs_only.pickle', 'rb') as f:
    fsq_df = pickle.load(f)

# %%
fsq_df = fsq_df[['venueId','venueCategory', 'latitude', 'longitude']].rename(columns={'latitude':'poi_lat', 'longitude':'poi_lon'})

# %%
fsq_df.shape
# Out:
# (7523, 4)

# %%
#reducing observations to unique venues/POIs for distance calculation
fsq_df_unique = fsq_df.groupby(by='venueId', as_index=False).max()
fsq_df_unique.shape
# Out:
# (2553, 4)

# %%
with open('weekly_avg_by_station_clean.pickle', 'rb') as f:
    entry_df = pickle.load(f)

# %%
entry_df = entry_df.sort_values('ENTRIES', ascending = False)

#only interested in top 10 stations
entry_df = entry_df.iloc[0:10]

# %%
#only interested in the station names and orders
distance_df = pd.DataFrame(entry_df.STATION)
distance_df.rename(columns={'STATION': 'station'}, inplace=True)

# %%
#manually update latitude/longitude for top 10
stat_lat_lons =[(40.750326,-73.988067), # 34 st - Herald Square
                (40.752962,-73.977219), # grand central - 42 st
                (40.750497,-73.990877), #34 st- penn station
                (40.741623,-73.989365), #23 st - actually 5th and 23rd st
                (40.755453,-73.987285), # Times Square - 42nd st
                (40.709641,-74.008283), #Fulton St
                (40.758923,-73.981350), #47-50 STS ROCK 
                (40.735019,-73.990698), # 14 st - Union Square
                (40.768868,-73.980959), #59 St Columbus
                (40.712925,-74.009928)] # PATH NEW WTC

# %%
distance_df['station_lat'] = [x[0] for x in stat_lat_lons]
distance_df['station_lon'] = [x[1] for x in stat_lat_lons]
distance_df
# Out:
#              station  station_lat  station_lon
# 58   34 ST-HERALD SQ    40.750326   -73.988067
# 232  GRD CNTRL-42 ST    40.752962   -73.977219
# 60    34 ST-PENN STA    40.750497   -73.990877
# 45             23 ST    40.741623   -73.989365
# 352   TIMES SQ-42 ST    40.755453   -73.987285
# 225        FULTON ST    40.709641   -74.008283
# 71    47-50 STS ROCK    40.758923   -73.981350
# 14    14 ST-UNION SQ    40.735019   -73.990698
# 85    59 ST COLUMBUS    40.768868   -73.980959
# 314     PATH NEW WTC    40.712925   -74.009928

# %%
#add column of all 1s to each df so we can merge to get all distances
distance_df['merge_column'] = 1
fsq_df_unique['merge_column'] = 1

distance_df = distance_df.merge(right=fsq_df_unique, on='merge_column')
distance_df.drop('merge_column', axis=1, inplace=True)

# %%
distance_df.head()
# Out:
#            station  station_lat  station_lon                   venueId  \
# 0  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5200eea1ee3
# 1  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5200fea1ee3
# 2  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a52010e41ee3
# 3  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5201ae61ee3
# 4  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5201be61ee3
#
#                      venueCategory    poi_lat    poi_lon
# 0                 Sushi Restaurant  40.727771 -74.000337
# 1                      Salad Place  40.739980 -73.986648
# 2  Molecular Gastronomy Restaurant  40.719649 -73.984607
# 3                 Sushi Restaurant  40.728898 -73.998128
# 4                   Clothing Store  40.722283 -73.999529

# %%
def distance_to_station(df_row):
    stat_coords = (df_row.station_lat, df_row.station_lon)
    poi_coords = (df_row.poi_lat, df_row.poi_lon)
    return haversine(stat_coords, poi_coords, miles=True)

# %%
distance_df['distance'] = distance_df.apply(distance_to_station, axis=1)

# %%
distance_df.head()
# Out:
#            station  station_lat  station_lon                   venueId  \
# 0  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5200eea1ee3
# 1  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5200fea1ee3
# 2  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a52010e41ee3
# 3  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5201ae61ee3
# 4  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5201be61ee3
#
#                      venueCategory    poi_lat    poi_lon  distance
# 0                 Sushi Restaurant  40.727771 -74.000337  1.685613
# 1                      Salad Place  40.739980 -73.986648  0.718688
# 2  Molecular Gastronomy Restaurant  40.719649 -73.984607  2.127333
# 3                 Sushi Restaurant  40.728898 -73.998128  1.571412
# 4                   Clothing Store  40.722283 -73.999529  2.028399

# %%
distance_df = distance_df[distance_df.distance < 1]
distance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4343 entries, 1 to 25517
# Data columns (total 8 columns):
# station          4343 non-null object
# station_lat      4343 non-null float64
# station_lon      4343 non-null float64
# venueId          4343 non-null object
# venueCategory    4343 non-null object
# poi_lat          4343 non-null float64
# poi_lon          4343 non-null float64
# distance         4343 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 305.4+ KB

# %%
with open('distance_df_v2.pickle','wb') as f:
    pickle.dump(distance_df, f)

# %%
distance_df.groupby(by=['venueCategory','station'], as_index=False).count().sort_values(['venueCategory','poi_lat'], ascending=[True,False])
# Out:
#           venueCategory          station  station_lat  station_lon  venueId  \
# 4          Antique Shop   47-50 STS ROCK            4            4        4
# 5          Antique Shop   59 ST COLUMBUS            4            4        4
# 7          Antique Shop   TIMES SQ-42 ST            4            4        4
# 0          Antique Shop   14 ST-UNION SQ            3            3        3
# 1          Antique Shop            23 ST            3            3        3
# 6          Antique Shop  GRD CNTRL-42 ST            3            3        3
# 2          Antique Shop  34 ST-HERALD SQ            1            1        1
# 3          Antique Shop   34 ST-PENN STA            1            1        1
# 10          Bridal Shop  34 ST-HERALD SQ            5            5        5
# 8           Bridal Shop   14 ST-UNION SQ            4            4        4
# 9           Bridal Shop            23 ST            4            4        4
# 11          Bridal Shop   34 ST-PENN STA            4            4        4
# 12          Bridal Shop   47-50 STS ROCK            4            4        4
# 16          Bridal Shop   TIMES SQ-42 ST            4            4        4
# 13          Bridal Shop   59 ST COLUMBUS            3            3        3
# 14          Bridal Shop  GRD CNTRL-42 ST            3            3        3
# 15          Bridal Shop     PATH NEW WTC            1            1        1
# 17       Clothing Store   14 ST-UNION SQ          313          313      313
# 18       Clothing Store            23 ST          227          227      227
# 19       Clothing Store  34 ST-HERALD SQ          219          219      219
# 20       Clothing Store   34 ST-PENN STA          212          212      212
# 21       Clothing Store   47-50 STS ROCK          201          201      201
# 24       Clothing Store  GRD CNTRL-42 ST          194          194      194
# 26       Clothing Store   TIMES SQ-42 ST          183          183      183
# 22       Clothing Store   59 ST COLUMBUS          149          149      149
# 25       Clothing Store     PATH NEW WTC          124          124      124
# 23       Clothing Store        FULTON ST           57           57       57
# 27       Cosmetics Shop   14 ST-UNION SQ           60           60       60
# 28       Cosmetics Shop            23 ST           60           60       60
# 30       Cosmetics Shop   34 ST-PENN STA           53           53       53
# ..                  ...              ...          ...          ...      ...
# 89   Salon / Barbershop   14 ST-UNION SQ           96           96       96
# 90   Salon / Barbershop            23 ST           79           79       79
# 96   Salon / Barbershop  GRD CNTRL-42 ST           72           72       72
# 93   Salon / Barbershop   47-50 STS ROCK           71           71       71
# 92   Salon / Barbershop   34 ST-PENN STA           67           67       67
# 98   Salon / Barbershop   TIMES SQ-42 ST           67           67       67
# 91   Salon / Barbershop  34 ST-HERALD SQ           66           66       66
# 94   Salon / Barbershop   59 ST COLUMBUS           45           45       45
# 97   Salon / Barbershop     PATH NEW WTC           25           25       25
# 95   Salon / Barbershop        FULTON ST           19           19       19
# 99        Spa / Massage   14 ST-UNION SQ           64           64       64
# 100       Spa / Massage            23 ST           58           58       58
# 108       Spa / Massage   TIMES SQ-42 ST           46           46       46
# 102       Spa / Massage   34 ST-PENN STA           45           45       45
# 106       Spa / Massage  GRD CNTRL-42 ST           44           44       44
# 103       Spa / Massage   47-50 STS ROCK           43           43       43
# 101       Spa / Massage  34 ST-HERALD SQ           42           42       42
# 104       Spa / Massage   59 ST COLUMBUS           23           23       23
# 107       Spa / Massage     PATH NEW WTC           19           19       19
# 105       Spa / Massage        FULTON ST           16           16       16
# 109    Sushi Restaurant   14 ST-UNION SQ           74           74       74
# 110    Sushi Restaurant            23 ST           70           70       70
# 111    Sushi Restaurant  34 ST-HERALD SQ           60           60       60
# 112    Sushi Restaurant   34 ST-PENN STA           59           59       59
# 118    Sushi Restaurant   TIMES SQ-42 ST           58           58       58
# 116    Sushi Restaurant  GRD CNTRL-42 ST           55           55       55
# 113    Sushi Restaurant   47-50 STS ROCK           53           53       53
# 114    Sushi Restaurant   59 ST COLUMBUS           33           33       33
# 117    Sushi Restaurant     PATH NEW WTC           14           14       14
# 115    Sushi Restaurant        FULTON ST           12           12       12
#
#      poi_lat  poi_lon  distance
# 4          4        4         4
# 5          4        4         4
# 7          4        4         4
# 0          3        3         3
# 1          3        3         3
# 6          3        3         3
# 2          1        1         1
# 3          1        1         1
# 10         5        5         5
# 8          4        4         4
# 9          4        4         4
# 11         4        4         4
# 12         4        4         4
# 16         4        4         4
# 13         3        3         3
# 14         3        3         3
# 15         1        1         1
# 17       313      313       313
# 18       227      227       227
# 19       219      219       219
# 20       212      212       212
# 21       201      201       201
# 24       194      194       194
# 26       183      183       183
# 22       149      149       149
# 25       124      124       124
# 23        57       57        57
# 27        60       60        60
# 28        60       60        60
# 30        53       53        53
# ..       ...      ...       ...
# 89        96       96        96
# 90        79       79        79
# 96        72       72        72
# 93        71       71        71
# 92        67       67        67
# 98        67       67        67
# 91        66       66        66
# 94        45       45        45
# 97        25       25        25
# 95        19       19        19
# 99        64       64        64
# 100       58       58        58
# 108       46       46        46
# 102       45       45        45
# 106       44       44        44
# 103       43       43        43
# 101       42       42        42
# 104       23       23        23
# 107       19       19        19
# 105       16       16        16
# 109       74       74        74
# 110       70       70        70
# 111       60       60        60
# 112       59       59        59
# 118       58       58        58
# 116       55       55        55
# 113       53       53        53
# 114       33       33        33
# 117       14       14        14
# 115       12       12        12
#
# [119 rows x 8 columns]
